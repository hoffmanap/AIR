# %%
import requests

cookies = {
    'ajs_anonymous_id': '26473f2c-4bdc-4c97-a08b-f1e5d810ed20',
    '_gcl_au': '1.1.129050256.1697217888',
    'amplitude_idundefinedairdna.co': 'eyJvcHRPdXQiOmZhbHNlLCJzZXNzaW9uSWQiOm51bGwsImxhc3RFdmVudFRpbWUiOm51bGwsImV2ZW50SWQiOjAsImlkZW50aWZ5SWQiOjAsInNlcXVlbmNlTnVtYmVyIjowfQ==',
    'hubspotutk': '95de2f9173fb7e816a91cfcf2906fae7',
    '__hssrc': '1',
    '_fbp': 'fb.1.1697217889404.1749555454',
    'ps_mode': 'trackingV1',
    '_hjSessionUser_71262': 'eyJpZCI6IjJhNGE3NjY0LTJjNmUtNWMyOS04ODk2LTk3ZjhlMWIxMGI4NyIsImNyZWF0ZWQiOjE2OTcyMTc4ODg2NzAsImV4aXN0aW5nIjp0cnVlfQ==',
    'idr-token': 'bAuaVORQMN0qZ8g7R-O5de7PUKZIvGQ9JN3oRar00_wBAnEQt2ML_g',
    'mmm-cookie': 'MTY0OTQ0Mw|f9ada4bf00ad4b888410f2e30fdddc0f',
    'ajs_user_id': '1649443',
    'intercom-device-id-kgkrrbqi': 'fcc4fa9b-62dc-419e-95c4-6dbd2dbd78f3',
    '_hjSession_71262': 'eyJpZCI6ImI1MzFlYTYwLWRmM2MtNDA3Mi1iYTYwLWIyZGE5ZDk4MjJmNSIsImNyZWF0ZWQiOjE2OTc4MTYwMDY1NzgsImluU2FtcGxlIjpmYWxzZSwic2Vzc2lvbml6ZXJCZXRhRW5hYmxlZCI6dHJ1ZX0=',
    '_hjAbsoluteSessionInProgress': '0',
    '_gid': 'GA1.2.361651398.1697816012',
    '__hstc': '265997264.95de2f9173fb7e816a91cfcf2906fae7.1697217888974.1697217888974.1697816014038.2',
    'id-token': 'eyJhbGciOiJIUzM4NCIsInR5cCI6IkpXVCIsImtpZCI6Ii1xRUFDM1daM2hPNWoxWlZISWRBQ252c01yQmt1YmxHIn0.....jzp_AnHIle0ZYxLEgNNe0DVPDNtHNvODINeJL5y1X2Kb9VdcMJILXhVC9CiRBW6k',
    'mmm-access-jwt-cookie': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJlbmNvZGVkX2FjY2Vzc190b2tlbiI6ImY5YWRhNGJmMDBhZDRiODg4NDEwZjJlMzBmZGRkYzBmIiwiZXhwIjoxNjk3OTAzODc2LCJwZXJtaXNzaW9ucyI6eyJjaXR5IjpbNTkwNTNdLCJyZWdpb24iOltdLCJjb3VudHJ5IjpbXSwic3RhdGUiOltdLCJ3b3JsZCI6ZmFsc2V9fQ.bGr3WymA9yOrtrzqVprssZW-51R2V8Fu0ELqMtWenhQ',
    'mmm-access-jwt-refresh-cookie': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJlbmNvZGVkX2FjY2Vzc190b2tlbiI6ImY5YWRhNGJmMDBhZDRiODg4NDEwZjJlMzBmZGRkYzBmIiwiZXhwIjoxNzAwNDA5NDc2fQ.M8_KzDkWMaE2PlVIb2ACpNy8Jbxl37D9LGppYpEU7Vo',
    'mm-csrf': '4ab2dc722347943a1848349ab1c4ae92ed65de431534759824be9cfe5c9c1679',
    '_hjIncludedInSessionSample_71262': '0',
    '_ga': 'GA1.2.1407354936.1697217887',
    '_ga_EQ37P58RZZ': 'GS1.2.1697816012.2.0.1697817479.60.0.0',
    '__hssc': '265997264.2.1697816014038',
eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJlbmNvZGVkX2FjY2Vzc190b2tlbiI6ImY5YWRhNGJmMDBhZDRiODg4NDEwZjJlMzBmZGRkYzBmIiwiZXhwIjoxNzAwNDA5NDc2fQ.M8_KzDkWMaE2PlVIb2ACpNy8Jbxl37D9LGppYpEU7Vo; mm-csrf=4ab2dc722347943a1848349ab1c4ae92ed65de431534759824be9cfe5c9c1679; _hjIncludedInSessionSample_71262=0; _ga=GA1.2.1407354936.1697217887; _ga_EQ37P58RZZ=GS1.2.1697816012.2.0.1697817479.60.0.0; __hssc=265997264.2.1697816014038; intercom-session-kgkrrbqi=MlBIeHNoTHdKUXBiNHQxam9jT21RYmFvQ3VLZkpmV2RJQjJucTJCcmJFMENwQUIrMlFoNEYyKzdwVFJ1dnlkdS0tWXhrKzlOUjkvMU56UGhKTnlYa0lPdz09--b8a955a571c694cf5e813000badc33c294fa5302; _ga_QJS7VP5707=GS1.1.1697816007.2.1.1697817532.4.0.0; _uetsid=0263d7106f5e11eead9765676577425a; _uetvid=6adfafa069ed11eeba9003a64e095bb2; amplitude_id_24ef8c5734b56d203283d7fa4245d68eairdna.co=',
    'origin': 'https://app.airdna.co',
    'referer': 'https://app.airdna.co/',
    'sec-ch-ua': '"Chromium";v="118", "Google Chrome";v="118", "Not=A?Brand";v="99"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36',
    'x-requested-with': 'disableCaseConversion',
}

json_data = {
    'filters': [
        {
            'type': 'multi_select',
            'field': 'market_id',
            'value': [
                79835,
                79645,
                72098,
                71821,
                72085,
                79484,
                71862,
                79853,
            ],
        },
    ],
    'currency': 'usd',
    'pagination': {
        'page_size': 4000,
        'offset': 0,
    },
    'only_return_cover_image': True,
}

response = requests.post(
    'https://api.airdna.co/api/explorer/v1/country/us/listings',
    cookies=cookies,
    headers=headers,
    json=json_data,
)

# Note: json_data will not be serialized by requests
# exactly as it was in the original request.
#data = '{"filters":[{"type":"multi_select","field":"market_id","value":[79835,79645,72098,71821,72085,79484,71862,79853]}],"currency":"usd","pagination":{"page_size":1000,"offset":0},"only_return_cover_image":true}'
#response = requests.post('https://api.airdna.co/api/explorer/v1/country/us/listings', cookies=cookies, headers=headers, data=data)

# %%
import pandas as pd

results = response.json()["payload"]["listings"]

airbnb_property_id, vrbo_property_id, listing_type, bedrooms, bathrooms, accommodates, rating, reviews, title, revenue_ltm, revenue_potential_ltm, occupancy_rate_ltm, average_daily_rate_ltm, days_available_ltm, lat, lon = zip(*((
    result["airbnb_property_id"],
    result["vrbo_property_id"],
    result["listing_type"],
    result["bedrooms"],
    result["bathrooms"],
    result["accommodates"],
    result["rating"],
    result["reviews"],
    result["title"],
    result["revenue_ltm"],
    result["revenue_potential_ltm"],
    result["occupancy_rate_ltm"],
    result["average_daily_rate_ltm"],
    result["days_available_ltm"],
    result["location"]["lat"],
    result["location"]["lng"]
)for result in results))

df = pd.DataFrame(
        {
        'airbnb_property_id' : airbnb_property_id,
        'vrbo_property_id' : vrbo_property_id,
        'listing_type' : listing_type,
        'bedrooms' : bedrooms,
        'bathrooms' : bathrooms,
        'accommodates' : accommodates,
        'rating' : rating,
        'reviews' : reviews,
        'title' : title,
        'revenue_ltm' : revenue_ltm,
        'revenue_potential_ltm' : revenue_potential_ltm,
        'occupancy_rate_ltm' : occupancy_rate_ltm,
        'average_daily_rate_ltm' : average_daily_rate_ltm,
        'days_available_ltm' : days_available_ltm,
        'lat' : lat,
        'lon' : lon})
df.to_csv("ep_str_data.csv", index = False)
